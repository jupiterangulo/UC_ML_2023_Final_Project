# %% [markdown]
# # Final Project Code
#
# Jupiter Angulo
# 02.26.23

# %%
import pandas as pd
import numpy as np
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.layers import Conv2D, Dense, Flatten, Dropout, Activation
from tensorflow.keras.layers import BatchNormalization, Reshape, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import load_model
import os
import random
from PIL import Image
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras import layers
#import torch
#import torchvision
#import torch.nn as nn
#import torch.optim as optim
#from torchvision import transforms
from vit_keras import vit, utils, visualize
from torch.utils.data import DataLoader
import tensorflow_addons as tfa
# Out:
# D:\Analytics\anaconda\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = "dataset/train"

df_labels = pd.read_csv('dataset/train.csv')

# %%
img_shape = (224, 224)
batch_size = 32


datagen = ImageDataGenerator(rescale=1/255., 
                            shear_range = 0.2,
                            zoom_range = 0.2,
                            horizontal_flip =True)

print('Training Images:')

df_data_res = datagen.flow_from_dataframe(dataframe=df_labels,
                                         directory = df,
                                         x_col='image_ID',
                                         y_col='label',
                                         target_size=img_shape,
                                         batch_size=batch_size,
                                         class_mode=None)
# Out:
# Training Images:
# Found 8227 validated image filenames.

# %%
df_labels['label'].value_counts()
# Out:
# Cricket      1556
# Wrestling    1471
# Tennis       1445
# Badminton    1394
# Soccer       1188
# Swimming      595
# Karate        578
# Name: label, dtype: int64

# %%
X = next(df_data_res) 

for i in range(0,9):
    plt.subplot(330 + 1 + i)
    plt.imshow(X[i, :, :, :])
    
plt.show()

# %%
df_data_res.image_shape
# Out:
# (224, 224, 3)

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %% [markdown]
# ## Train Test Split

# %%
validation_split = 0.8
train_split = 0.75
idxs = np.random.permutation(range(len(df_labels)))

train_idxs = idxs[:int(train_split * len(idxs))]
val_idxs = idxs[int(train_split * len(idxs)):int(validation_split * len(idxs))]
test_idxs = idxs[int(validation_split * len(idxs)):]

train_labels = df_labels.iloc[train_idxs]
val_labels = df_labels.iloc[val_idxs]
test_labels = df_labels.iloc[test_idxs]

print(len(train_labels), len(test_labels), len(val_labels))
# Out:
# 6170 1646 411

# %%
# Augment the training generator
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale = 1. / 255,
    shear_range = 0.5,
    zoom_range = 0.5,
    rotation_range = 50,
    width_shift_range = 0.2,
    height_shift_range = 0.2,
    horizontal_flip = True,
    vertical_flip = True
)

# Use consistent rescaling for validation and test generators
validation_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1. / 255)
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1. / 255)

# %%
# Set batch size and image shape
#batch_size = 32
#img_shape = (64, 64)

train_generator = train_datagen.flow_from_dataframe(
    train_labels,
    directory = df,
    x_col = 'image_ID',
    y_col = 'label',
    class_mode = 'categorical',
    batch_size = batch_size,
    target_size = img_shape
)

test_generator = test_datagen.flow_from_dataframe(
    test_labels,
    directory = df,
    x_col = 'image_ID',
    y_col = 'label',
    class_mode = 'categorical',
    batch_size = batch_size,
    target_size = img_shape
)


validation_generator = validation_datagen.flow_from_dataframe(
    val_labels,
    directory = df,
    x_col = 'image_ID',
    y_col = 'label',
    class_mode = 'categorical',
    batch_size = batch_size,
    target_size = img_shape
)
# Out:
# Found 6170 validated image filenames belonging to 7 classes.
# Found 1646 validated image filenames belonging to 7 classes.
# Found 411 validated image filenames belonging to 7 classes.

# %% [markdown]
# ## InceptionV3

# %%
base_model = tf.keras.applications.InceptionV3(input_shape=(224,224,3),include_top=False,weights="imagenet")
# Out:
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.2.true_positives
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.2.false_positives
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.3.true_positives
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.3.false_negatives
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.4.true_positives
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.4.true_negatives
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.4.false_positives
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.4.false_negatives

# %%
for layer in base_model.layers[:-10]:
    layer.trainable=False

# %%
model=Sequential()
model.add(base_model)
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(7, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  dropout (Dropout)           (None, 5, 5, 2048)        0
#
#  flatten (Flatten)           (None, 51200)             0
#
#  dense (Dense)               (None, 128)               6553728
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 28,373,927
# Trainable params: 6,571,335
# Non-trainable params: 21,802,592
# _________________________________________________________________

# %%
METRICS = [
      tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
]



mcp = ModelCheckpoint('model.h5')

es = EarlyStopping(verbose=1, patience=3)

# %%
model.compile(optimizer='Adam', loss = tf.keras.losses.CategoricalCrossentropy(), metrics=METRICS)

# %%
# %time
history=model.fit(train_generator,validation_data=validation_generator,epochs = 10,verbose = 1,callbacks=[mcp,es])
# Out:
# Wall time: 0 ns
# Epoch 1/10
# 193/193 [==============================] - 311s 2s/step - loss: 2.0130 - accuracy: 0.5982 - precision: 0.6330 - recall: 0.5686 - auc: 0.8700 - val_loss: 0.9372 - val_accuracy: 0.6959 - val_precision: 0.7161 - val_recall: 0.6691 - val_auc: 0.9364
# Epoch 2/10
# 193/193 [==============================] - 238s 1s/step - loss: 0.7914 - accuracy: 0.7417 - precision: 0.7737 - recall: 0.7063 - auc: 0.9507 - val_loss: 0.6896 - val_accuracy: 0.7737 - val_precision: 0.8041 - val_recall: 0.7689 - val_auc: 0.9604
# Epoch 3/10
# 193/193 [==============================] - 259s 1s/step - loss: 0.6954 - accuracy: 0.7627 - precision: 0.8038 - recall: 0.7303 - auc: 0.9601 - val_loss: 0.5981 - val_accuracy: 0.7883 - val_precision: 0.8194 - val_recall: 0.7616 - val_auc: 0.9696
# Epoch 4/10
# 193/193 [==============================] - 267s 1s/step - loss: 0.6838 - accuracy: 0.7677 - precision: 0.8071 - recall: 0.7376 - auc: 0.9609 - val_loss: 0.5334 - val_accuracy: 0.8078 - val_precision: 0.8364 - val_recall: 0.7835 - val_auc: 0.9739
# Epoch 5/10
# 193/193 [==============================] - 295s 2s/step - loss: 0.6107 - accuracy: 0.7961 - precision: 0.8353 - recall: 0.7684 - auc: 0.9667 - val_loss: 0.5688 - val_accuracy: 0.8175 - val_precision: 0.8519 - val_recall: 0.7981 - val_auc: 0.9714
# Epoch 6/10
# 193/193 [==============================] - 279s 1s/step - loss: 0.6270 - accuracy: 0.7883 - precision: 0.8226 - recall: 0.7606 - auc: 0.9662 - val_loss: 0.4888 - val_accuracy: 0.8467 - val_precision: 0.8633 - val_recall: 0.8297 - val_auc: 0.9769
# Epoch 7/10
# 193/193 [==============================] - 259s 1s/step - loss: 0.5987 - accuracy: 0.7937 - precision: 0.8255 - recall: 0.7695 - auc: 0.9689 - val_loss: 0.5035 - val_accuracy: 0.8297 - val_precision: 0.8520 - val_recall: 0.8127 - val_auc: 0.9730
# Epoch 8/10
# 193/193 [==============================] - 264s 1s/step - loss: 0.5980 - accuracy: 0.7940 - precision: 0.8286 - recall: 0.7687 - auc: 0.9692 - val_loss: 0.4894 - val_accuracy: 0.8540 - val_precision: 0.8724 - val_recall: 0.8321 - val_auc: 0.9745
# Epoch 9/10
# 193/193 [==============================] - 254s 1s/step - loss: 0.5198 - accuracy: 0.8196 - precision: 0.8482 - recall: 0.7917 - auc: 0.9760 - val_loss: 0.5358 - val_accuracy: 0.8443 - val_precision: 0.8663 - val_recall: 0.8200 - val_auc: 0.9747
# Epoch 9: early stopping

# %%
history.model.evaluate(test_generator)
# Out:
# 44/52 [========================>.....] - ETA: 11s - loss: 0.3952 - accuracy: 0.8615 - precision: 0.8768 - recall: 0.8438 - auc: 0.9851Collecting transformers
#   Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      ---------------------------------------- 6.3/6.3 MB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in d:\analytics\anaconda\lib\site-packages (from transformers) (3.3.1)
# Requirement already satisfied: packaging>=20.0 in d:\analytics\anaconda\lib\site-packages (from transformers) (21.0)
# Requirement already satisfied: pyyaml>=5.1 in d:\analytics\anaconda\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in d:\analytics\anaconda\lib\site-packages (from transformers) (2021.8.3)
# Requirement already satisfied: requests in d:\analytics\anaconda\lib\site-packages (from transformers) (2.26.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-win_amd64.whl (3.3 MB)
#      ---------------------------------------- 3.3/3.3 MB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in d:\analytics\anaconda\lib\site-packages (from transformers) (1.20.3)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.12.1-py3-none-any.whl (190 kB)
#      -------------------------------------- 190.3/190.3 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in d:\analytics\anaconda\lib\site-packages (from transformers) (4.62.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\analytics\anaconda\lib\site-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\analytics\anaconda\lib\site-packages (from packaging>=20.0->transformers) (3.0.4)
# Requirement already satisfied: colorama in d:\analytics\anaconda\lib\site-packages (from tqdm>=4.27->transformers) (0.4.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\analytics\anaconda\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\analytics\anaconda\lib\site-packages (from requests->transformers) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in d:\analytics\anaconda\lib\site-packages (from requests->transformers) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\analytics\anaconda\lib\site-packages (from requests->transformers) (2022.12.7)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.12.1 tokenizers-0.13.2 transformers-4.26.1
# WARNING: Ignoring invalid distribution -ip (d:\analytics\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\analytics\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\analytics\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\analytics\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\analytics\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\analytics\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\analytics\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\analytics\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\analytics\anaconda\lib\site-packages)
# 52/52 [==============================] - 74s 1s/step - loss: 0.3783 - accuracy: 0.8663 - precision: 0.8816 - recall: 0.8505 - auc: 0.9864
# [0.37827038764953613,
#  0.8663426637649536,
#  0.8816120624542236,
#  0.8505467772483826,
#  0.9863536953926086]

# %% [markdown]
# ## Transfer Learning

# %%
vgg_base_model=keras.applications.VGG16(
weights="imagenet",   # Load weights pre-trained on ImageNet.
input_shape=(224,224,3),
include_top=False) # Do not include the ImageNet classifier at the top.
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step

# %%
for l in vgg_base_model.layers:
    print(l.name,l.trainable)
# Out:
# input_34 True
# block1_conv1 True
# block1_conv2 True
# block1_pool True
# block2_conv1 True
# block2_conv2 True
# block2_pool True
# block3_conv1 True
# block3_conv2 True
# block3_conv3 True
# block3_pool True
# block4_conv1 True
# block4_conv2 True
# block4_conv3 True
# block4_pool True
# block5_conv1 True
# block5_conv2 True
# block5_conv3 True
# block5_pool True

# %%
vgg_base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_34 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
for l in vgg_base_model.layers[:-4]:
    l.trainable=False

# %%
for l in vgg_base_model.layers:
    print(l.name, l.trainable)
# Out:
# input_34 False
# block1_conv1 False
# block1_conv2 False
# block1_pool False
# block2_conv1 False
# block2_conv2 False
# block2_pool False
# block3_conv1 False
# block3_conv2 False
# block3_conv3 False
# block3_pool False
# block4_conv1 False
# block4_conv2 False
# block4_conv3 False
# block4_pool False
# block5_conv1 True
# block5_conv2 True
# block5_conv3 True
# block5_pool True

# %%
inputs=keras.Input(shape=(224,224,3))

x=vgg_base_model(inputs)
# Convert the features of shape base_model.output_shape[1:] to vectors
x=keras.layers.GlobalAveragePooling2D()(x)
# A Dense classifier with a 7 unit (multiclass classification)
x=keras.layers.Dense(512,activation="relu")(x)
x=keras.layers.Dropout(0.3)(x)

outputs=keras.layers.Dense(7,activation="softmax")(x)
model=keras.Model(inputs,outputs)

# %%
model.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_35 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense_52 (Dense)            (None, 512)               262656
#
#  dropout_46 (Dropout)        (None, 512)               0
#
#  dense_53 (Dense)            (None, 7)                 3591
#
# =================================================================
# Total params: 14,980,935
# Trainable params: 7,345,671
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.Adam(learning_rate=0.0001), metrics=['accuracy'])
earlyStopping = EarlyStopping(monitor='val_loss', patience=5, verbose=0, mode='min')
mcp_save = ModelCheckpoint('vgg_mdl_wts_0.0001.hdf5', save_best_only=True, monitor='val_loss', mode='min')

history_vgg=model.fit(train_generator,epochs=3,validation_data=validation_generator,callbacks=[earlyStopping, mcp_save])
# Out:
# Epoch 1/3
# 193/193 [==============================] - 4158s 22s/step - loss: 1.1136 - accuracy: 0.5940 - val_loss: 0.6871 - val_accuracy: 0.7883
# Epoch 2/3
# 193/193 [==============================] - 4027s 21s/step - loss: 0.6667 - accuracy: 0.7682 - val_loss: 0.4842 - val_accuracy: 0.8589
# Epoch 3/3
# 193/193 [==============================] - 4206s 22s/step - loss: 0.5205 - accuracy: 0.8152 - val_loss: 0.5187 - val_accuracy: 0.8297

# %%
history_vgg.model.evaluate(test_generator)
# Out:
# 52/52 [==============================] - 987s 19s/step - loss: 0.4723 - accuracy: 0.8354
# [0.47234615683555603, 0.8353584408760071]

# %%
history_vgg.model.save('vgg16_model_ja')
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x0000020A91876B80> and will run it as-is.
# Cause: Unable to locate the source code of <function trace_model_call.<locals>._wrapped_model at 0x0000020A91876B80>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x0000020A91876B80> and will run it as-is.
# Cause: Unable to locate the source code of <function trace_model_call.<locals>._wrapped_model at 0x0000020A91876B80>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: vgg16_model_ja\assets
# INFO:tensorflow:Assets written to: vgg16_model_ja\assets

# %%
model.save('vit_l32_model_ja')
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x0000020CE0C41DC0> and will run it as-is.
# Cause: Unable to locate the source code of <function trace_model_call.<locals>._wrapped_model at 0x0000020CE0C41DC0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x0000020CE0C41DC0> and will run it as-is.
# Cause: Unable to locate the source code of <function trace_model_call.<locals>._wrapped_model at 0x0000020CE0C41DC0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x0000020CE0C41DC0> and will run it as-is.
# Cause: Unable to locate the source code of <function trace_model_call.<locals>._wrapped_model at 0x0000020CE0C41DC0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: vit_l32_model_ja\assets
# INFO:tensorflow:Assets written to: vit_l32_model_ja\assets

# %%
history.model.save('inceptionv3_model_ja')
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x0000020A91876B80> and will run it as-is.
# Cause: Unable to locate the source code of <function trace_model_call.<locals>._wrapped_model at 0x0000020A91876B80>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x0000020A91876B80> and will run it as-is.
# Cause: Unable to locate the source code of <function trace_model_call.<locals>._wrapped_model at 0x0000020A91876B80>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x0000020A91876B80> and will run it as-is.
# Cause: Unable to locate the source code of <function trace_model_call.<locals>._wrapped_model at 0x0000020A91876B80>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:absl:Found untraced functions such as _update_step_xla, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 95). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: inceptionv3_model_ja\assets
# INFO:tensorflow:Assets written to: inceptionv3_model_ja\assets

# %% [markdown]
# ViT_l32

# %%
image_size = 224
model = vit.vit_l32(
    image_size=image_size,
    activation='sigmoid',
    pretrained=True,
    include_top=True,
    pretrained_top=False,
    classes=7
)

# Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss='categorical_crossentropy',
    metrics=['accuracy'])

# Train the model using the data generators
model.fit(
    train_generator,
    steps_per_epoch=50,
    epochs=10,
    validation_data=validation_generator,
    validation_steps=10
)

# %%
model.evaluate(test_generator)

##Accuracy is horrible going to try softmax
# Out:
# 52/52 [==============================] - 321s 6s/step - loss: 1.2147 - accuracy: 0.5194
# [1.214692234992981, 0.5194410681724548]

# %%
# Load a model
image_size = (224,224)
classes = utils.get_imagenet_classes()
model = vit.vit_b16(
    image_size=image_size,
    activation='sigmoid',
    pretrained=True,
    include_top=True,
    pretrained_top=True
)
classes = utils.get_imagenet_classes()

# Get an image and compute the attention map
image = cv2.imread('dataset/train/00a87b6bb3.jpg')
img1 =  cv2.resize(image, (224,224)) 
attention_map = visualize.attention_map(model=model, image=img1)
print('Prediction:', classes[
    model.predict(vit.preprocess_inputs(img1)[np.newaxis])[0].argmax()]
) 

# Plot results
fig, (ax1, ax2) = plt.subplots(ncols=2)
ax1.axis('off')
ax2.axis('off')
ax1.set_title('Original')
ax2.set_title('Attention Map')
_ = ax1.imshow(image)
_ = ax2.imshow(attention_map)
# Out:
# D:\Analytics\anaconda\lib\site-packages\vit_keras\utils.py:81: UserWarning: Resizing position embeddings from 24, 24 to 14, 14
#   warnings.warn(
# 1/1 [==============================] - 4s 4s/step

# %%
## Load Model

inception_model = tf.keras.models.load_model('inceptionv3_model_ja', compile=False)

# %%
inception_model.compile(optimizer='Adam', loss = tf.keras.losses.CategoricalCrossentropy(), metrics=METRICS)

# %%
inception_model.evaluate(test_generator)
# Out:
# 52/52 [==============================] - 34s 255ms/step - loss: 0.3426 - accuracy: 0.8840 - precision: 0.8987 - recall: 0.8682 - auc: 0.9881
# [0.34264224767684937,
#  0.8839611411094666,
#  0.898742139339447,
#  0.8681652545928955,
#  0.9880970120429993]

# %%
inception_model

# %%
# Get an image and compute the attention map
image = cv2.imread('dataset/test/4e5421f6d4.jpg')

img1 = cv2.resize(image, (224, 224))
#image = np.expand_dims(image, axis=0)
#image = image / 255.0  # normalize pixel values to [0, 1]

model = vit.vit_l32(
    image_size=224,
    activation='sigmoid',
    pretrained_top=False,
    include_top=True,
    pretrained=True,
)

# Load the Keras model
model.load_weights('vit_l32_model_ja')



# Get the attention map
attention_map = visualize.attention_map(model, img1)

# Display the attention map
fig, (ax1, ax2) = plt.subplots(figsize=(10, 10), ncols=2)
ax1.axis('off')
ax2.axis('off')
ax1.set_title('Original')
ax2.set_title('Attention Map')
_ = ax1.imshow(img1)
_ = ax2.imshow(attention_map)

#cv2.waitKey(0)
#cv2.destroyAllWindows()
# Out:
# D:\Analytics\anaconda\lib\site-packages\vit_keras\utils.py:81: UserWarning: Resizing position embeddings from 12, 12 to 7, 7
#   warnings.warn(
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<vit_keras.layers.AddPositionEmbs object at 0x000002124C1818B0> and <vit_keras.layers.TransformerBlock object at 0x000002124C284070>).
# 1/1 [==============================] - 9s 9s/step

# %%
# Get an image and compute the attention map
image = cv2.imread('dataset/test/7cc5e4fc2f.jpg')

img1 = cv2.resize(image, (224, 224))
#image = np.expand_dims(image, axis=0)
#image = image / 255.0  # normalize pixel values to [0, 1]

model = vit.vit_l32(
    image_size=224,
    activation='sigmoid',
    pretrained_top=False,
    include_top=True,
    pretrained=True,
)

# Load the Keras model
model.load_weights('vit_l32_model_ja')



# Get the attention map
attention_map = visualize.attention_map(model, img1)

# Display the attention map
fig, (ax1, ax2) = plt.subplots(figsize=(10, 10), ncols=2)
ax1.axis('off')
ax2.axis('off')
ax1.set_title('Original')
ax2.set_title('Attention Map')
_ = ax1.imshow(img1)
_ = ax2.imshow(attention_map)

#cv2.waitKey(0)
#cv2.destroyAllWindows()
# Out:
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<vit_keras.layers.AddPositionEmbs object at 0x000002137A7CFA00> and <vit_keras.layers.TransformerBlock object at 0x000002137DBEB430>).
# 1/1 [==============================] - 6s 6s/step

# %%
# Get an image and compute the attention map
image = cv2.imread('dataset/test/2f6a05c3ab.jpg')

img1 = cv2.resize(image, (224, 224))
#image = np.expand_dims(image, axis=0)
#image = image / 255.0  # normalize pixel values to [0, 1]

model = vit.vit_l32(
    image_size=224,
    activation='sigmoid',
    pretrained_top=False,
    include_top=True,
    pretrained=True,
)

# Load the Keras model
model.load_weights('vit_l32_model_ja')



# Get the attention map
attention_map = visualize.attention_map(model, img1)

# Display the attention map
fig, (ax1, ax2) = plt.subplots(figsize=(10, 10), ncols=2)
ax1.axis('off')
ax2.axis('off')
ax1.set_title('Original')
ax2.set_title('Attention Map')
_ = ax1.imshow(img1)
_ = ax2.imshow(attention_map)

#cv2.waitKey(0)
#cv2.destroyAllWindows()
# Out:
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).layer_with_weights-1.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).layer_with_weights-1.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).layer_with_weights-2.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).layer_with_weights-2.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.0
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.5
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.6
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.7
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.8
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.9
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.10
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.11
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.12
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.13
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.14
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.15
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.16
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.17
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.18
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.19
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.20
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.21
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.22
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.23
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.24
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.25
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).layer_with_weights-1.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).layer_with_weights-1.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).layer_with_weights-2.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).layer_with_weights-2.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).variables.20
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).variables.21
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).variables.22
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).variables.23
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).variables.24
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).variables.25
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).layer_with_weights-1.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).layer_with_weights-1.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).layer_with_weights-2.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).layer_with_weights-2.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).variables.20
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).variables.21
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).variables.22
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).variables.23
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).variables.24
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).variables.25
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<vit_keras.layers.AddPositionEmbs object at 0x0000021398112310> and <vit_keras.layers.TransformerBlock object at 0x000002139BD4FB80>).
# 1/1 [==============================] - 6s 6s/step

# %%
# Get an image and compute the attention map
image = cv2.imread('dataset/train/0a68eeff6e.jpg')

img1 = cv2.resize(image, (224, 224))
#image = np.expand_dims(image, axis=0)
#image = image / 255.0  # normalize pixel values to [0, 1]

model = vit.vit_l32(
    image_size=224,
    activation='sigmoid',
    pretrained_top=False,
    include_top=True,
    pretrained=True,
)

# Load the Keras model
model.load_weights('vit_l32_model_ja')



# Get the attention map
attention_map = visualize.attention_map(model, img1)

# Display the attention map
fig, (ax1, ax2) = plt.subplots(figsize=(10, 10), ncols=2)
ax1.axis('off')
ax2.axis('off')
ax1.set_title('Original')
ax2.set_title('Attention Map')
_ = ax1.imshow(img1)
_ = ax2.imshow(attention_map)

#cv2.waitKey(0)
#cv2.destroyAllWindows()
# Out:
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).layer_with_weights-1.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).layer_with_weights-1.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).layer_with_weights-2.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).layer_with_weights-2.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.0
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.5
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.6
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.7
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.8
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.9
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.10
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.11
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.12
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.13
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.14
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.15
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.16
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.17
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.18
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.19
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.20
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.21
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.22
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.23
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.24
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.25
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).layer_with_weights-1.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).layer_with_weights-1.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).layer_with_weights-2.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).layer_with_weights-2.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).variables.20
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).variables.21
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).variables.22
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).variables.23
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).variables.24
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).variables.25
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).layer_with_weights-1.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).layer_with_weights-1.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).layer_with_weights-2.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).layer_with_weights-2.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).variables.20
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).variables.21
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).variables.22
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).variables.23
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).variables.24
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).variables.25
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<vit_keras.layers.AddPositionEmbs object at 0x0000021397BEEBB0> and <vit_keras.layers.TransformerBlock object at 0x000002137614D7C0>).
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000213A603B160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 8s 8s/step

# %%
# Get an image and compute the attention map
image = cv2.imread('dataset/train/0b98a88c66.jpg')

img1 = cv2.resize(image, (224, 224))
#image = np.expand_dims(image, axis=0)
#image = image / 255.0  # normalize pixel values to [0, 1]

model = vit.vit_l32(
    image_size=224,
    activation='sigmoid',
    pretrained_top=False,
    include_top=True,
    pretrained=True,
)

# Load the Keras model
model.load_weights('vit_l32_model_ja')



# Get the attention map
attention_map = visualize.attention_map(model, img1)

# Display the attention map
fig, (ax1, ax2) = plt.subplots(figsize=(10, 10), ncols=2)
ax1.axis('off')
ax2.axis('off')
ax1.set_title('Original')
ax2.set_title('Attention Map')
_ = ax1.imshow(img1)
_ = ax2.imshow(attention_map)

#cv2.waitKey(0)
#cv2.destroyAllWindows()
# Out:
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).layer_with_weights-1.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).layer_with_weights-1.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).layer_with_weights-2.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).layer_with_weights-2.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.0
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.5
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.6
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.7
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.8
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.9
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.10
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.11
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.12
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.13
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.14
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.15
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.16
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.17
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.18
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.19
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.20
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.21
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.22
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.23
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.24
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).variables.25
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).layer_with_weights-1.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).layer_with_weights-1.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).layer_with_weights-2.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).layer_with_weights-2.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).variables.20
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).variables.21
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).variables.22
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).variables.23
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).variables.24
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).variables.25
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).layer_with_weights-1.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).layer_with_weights-1.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).layer_with_weights-2.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).layer_with_weights-2.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).variables.20
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).variables.21
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).variables.22
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).variables.23
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).variables.24
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).variables.25
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<vit_keras.layers.AddPositionEmbs object at 0x00000213856CA100> and <vit_keras.layers.TransformerBlock object at 0x00000213A60DC730>).
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002137618CE50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 7s 7s/step

# %%
image_size = 224
vit_model = vit.vit_l32(
    image_size=image_size,
    activation='softmax',
    pretrained=True,
    include_top=True,
    pretrained_top=False,
    classes=7
)

# %%
for l in vit_model.layers:
    print(l.name,l.trainable)
# Out:
# input_2 False
# embedding False
# reshape_1 False
# class_token False
# Transformer/posembed_input False
# Transformer/encoderblock_0 False
# Transformer/encoderblock_1 False
# Transformer/encoderblock_2 False
# Transformer/encoderblock_3 False
# Transformer/encoderblock_4 False
# Transformer/encoderblock_5 False
# Transformer/encoderblock_6 False
# Transformer/encoderblock_7 False
# Transformer/encoderblock_8 False
# Transformer/encoderblock_9 False
# Transformer/encoderblock_10 False
# Transformer/encoderblock_11 False
# Transformer/encoderblock_12 False
# Transformer/encoderblock_13 False
# Transformer/encoderblock_14 False
# Transformer/encoderblock_15 False
# Transformer/encoderblock_16 False
# Transformer/encoderblock_17 False
# Transformer/encoderblock_18 False
# Transformer/encoderblock_19 False
# Transformer/encoderblock_20 False
# Transformer/encoderblock_21 False
# Transformer/encoderblock_22 False
# Transformer/encoderblock_23 True
# Transformer/encoder_norm True
# ExtractToken True
# head True

# %%
for l in vit_model.layers[:-4]:
    l.trainable=False
    print(l.name, l.trainable)
# Out:
# input_2 False
# embedding False
# reshape_1 False
# class_token False
# Transformer/posembed_input False
# Transformer/encoderblock_0 False
# Transformer/encoderblock_1 False
# Transformer/encoderblock_2 False
# Transformer/encoderblock_3 False
# Transformer/encoderblock_4 False
# Transformer/encoderblock_5 False
# Transformer/encoderblock_6 False
# Transformer/encoderblock_7 False
# Transformer/encoderblock_8 False
# Transformer/encoderblock_9 False
# Transformer/encoderblock_10 False
# Transformer/encoderblock_11 False
# Transformer/encoderblock_12 False
# Transformer/encoderblock_13 False
# Transformer/encoderblock_14 False
# Transformer/encoderblock_15 False
# Transformer/encoderblock_16 False
# Transformer/encoderblock_17 False
# Transformer/encoderblock_18 False
# Transformer/encoderblock_19 False
# Transformer/encoderblock_20 False
# Transformer/encoderblock_21 False
# Transformer/encoderblock_22 False

# %%
# Compile the model
vit_model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss='categorical_crossentropy',
    metrics=['accuracy'])

# Train the model using the data generators
vit_model.fit(
    train_generator,
    steps_per_epoch=50,
    epochs=10,
    validation_data=validation_generator,
    validation_steps=10
)
# Out:
# Epoch 1/10
# 50/50 [==============================] - 90s 985ms/step - loss: 1.0180 - accuracy: 0.6518 - val_loss: 0.1968 - val_accuracy: 0.9312
# Epoch 2/10
# 50/50 [==============================] - 42s 832ms/step - loss: 0.6751 - accuracy: 0.7713 - val_loss: 0.2187 - val_accuracy: 0.9281
# Epoch 3/10
# 50/50 [==============================] - 40s 795ms/step - loss: 0.6021 - accuracy: 0.7987 - val_loss: 0.1295 - val_accuracy: 0.9531
# Epoch 4/10
# 50/50 [==============================] - 38s 759ms/step - loss: 0.5486 - accuracy: 0.8056 - val_loss: 0.1420 - val_accuracy: 0.9531
# Epoch 5/10
# 50/50 [==============================] - 37s 738ms/step - loss: 0.5031 - accuracy: 0.8219 - val_loss: 0.1519 - val_accuracy: 0.9563
# Epoch 6/10
# 50/50 [==============================] - 37s 730ms/step - loss: 0.4719 - accuracy: 0.8425 - val_loss: 0.1385 - val_accuracy: 0.9500
# Epoch 7/10
# 50/50 [==============================] - 40s 784ms/step - loss: 0.4839 - accuracy: 0.8294 - val_loss: 0.1657 - val_accuracy: 0.9469
# Epoch 8/10
# 50/50 [==============================] - 44s 872ms/step - loss: 0.4007 - accuracy: 0.8537 - val_loss: 0.1218 - val_accuracy: 0.9469
# Epoch 9/10
# 50/50 [==============================] - 41s 808ms/step - loss: 0.4127 - accuracy: 0.8576 - val_loss: 0.1592 - val_accuracy: 0.9500
# Epoch 10/10
# 50/50 [==============================] - 38s 757ms/step - loss: 0.4261 - accuracy: 0.8500 - val_loss: 0.1288 - val_accuracy: 0.9563

# %%
vit_model.evaluate(test_generator)
# Out:
# 52/52 [==============================] - 33s 637ms/step - loss: 0.2285 - accuracy: 0.9228
# [0.22849257290363312, 0.9228432774543762]

# %%
vit_model.summary()
# Out:
# Model: "vit-l32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  embedding (Conv2D)          (None, 7, 7, 1024)        3146752
#
#  reshape_1 (Reshape)         (None, 49, 1024)          0
#
#  class_token (ClassToken)    (None, 50, 1024)          1024
#
#  Transformer/posembed_input   (None, 50, 1024)         51200
#  (AddPositionEmbs)
#
#  Transformer/encoderblock_0   ((None, 50, 1024),       12596224
#  (TransformerBlock)           (None, 16, None, None))
#
#  Transformer/encoderblock_1   ((None, 50, 1024),       12596224
#  (TransformerBlock)           (None, 16, None, None))
#
#  Transformer/encoderblock_2   ((None, 50, 1024),       12596224
#  (TransformerBlock)           (None, 16, None, None))
#
#  Transformer/encoderblock_3   ((None, 50, 1024),       12596224
#  (TransformerBlock)           (None, 16, None, None))
#
#  Transformer/encoderblock_4   ((None, 50, 1024),       12596224
#  (TransformerBlock)           (None, 16, None, None))
#
#  Transformer/encoderblock_5   ((None, 50, 1024),       12596224
#  (TransformerBlock)           (None, 16, None, None))
#
#  Transformer/encoderblock_6   ((None, 50, 1024),       12596224
#  (TransformerBlock)           (None, 16, None, None))
#
#  Transformer/encoderblock_7   ((None, 50, 1024),       12596224
#  (TransformerBlock)           (None, 16, None, None))
#
#  Transformer/encoderblock_8   ((None, 50, 1024),       12596224
#  (TransformerBlock)           (None, 16, None, None))
#
#  Transformer/encoderblock_9   ((None, 50, 1024),       12596224
#  (TransformerBlock)           (None, 16, None, None))
#
#  Transformer/encoderblock_10  ((None, 50, 1024),       12596224
#   (TransformerBlock)          (None, 16, None, None))
#
#  Transformer/encoderblock_11  ((None, 50, 1024),       12596224
#   (TransformerBlock)          (None, 16, None, None))
#
#  Transformer/encoderblock_12  ((None, 50, 1024),       12596224
#   (TransformerBlock)          (None, 16, None, None))
#
#  Transformer/encoderblock_13  ((None, 50, 1024),       12596224
#   (TransformerBlock)          (None, 16, None, None))
#
#  Transformer/encoderblock_14  ((None, 50, 1024),       12596224
#   (TransformerBlock)          (None, 16, None, None))
#
#  Transformer/encoderblock_15  ((None, 50, 1024),       12596224
#   (TransformerBlock)          (None, 16, None, None))
#
#  Transformer/encoderblock_16  ((None, 50, 1024),       12596224
#   (TransformerBlock)          (None, 16, None, None))
#
#  Transformer/encoderblock_17  ((None, 50, 1024),       12596224
#   (TransformerBlock)          (None, 16, None, None))
#
#  Transformer/encoderblock_18  ((None, 50, 1024),       12596224
#   (TransformerBlock)          (None, 16, None, None))
#
#  Transformer/encoderblock_19  ((None, 50, 1024),       12596224
#   (TransformerBlock)          (None, 16, None, None))
#
#  Transformer/encoderblock_20  ((None, 50, 1024),       12596224
#   (TransformerBlock)          (None, 16, None, None))
#
#  Transformer/encoderblock_21  ((None, 50, 1024),       12596224
#   (TransformerBlock)          (None, 16, None, None))
#
#  Transformer/encoderblock_22  ((None, 50, 1024),       12596224
#   (TransformerBlock)          (None, 16, None, None))
#
#  Transformer/encoderblock_23  ((None, 50, 1024),       12596224
#   (TransformerBlock)          (None, 16, None, None))
#
#  Transformer/encoder_norm (L  (None, 50, 1024)         2048
#  ayerNormalization)
#
#  ExtractToken (Lambda)       (None, 1024)              0
#
#  head (Dense)                (None, 7)                 7175
#
# =================================================================
# Total params: 305,517,575
# Trainable params: 12,605,447
# Non-trainable params: 292,912,128
# _________________________________________________________________

# %%
# Get an image and compute the attention map
image = cv2.imread('dataset/test/2f6a05c3ab.jpg')

img1 = cv2.resize(image, (224, 224))
#image = np.expand_dims(image, axis=0)
#image = image / 255.0  # normalize pixel values to [0, 1]




# Get the attention map
attention_map = visualize.attention_map(vit_model, img1)

# Display the attention map
fig, (ax1, ax2) = plt.subplots(figsize=(10, 10), ncols=2)
ax1.axis('off')
ax2.axis('off')
ax1.set_title('Original')
ax2.set_title('Attention Map')
_ = ax1.imshow(img1)
_ = ax2.imshow(attention_map)

#cv2.waitKey(0)
#cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 8s 8s/step

# %%
# Get an image and compute the attention map
image = cv2.imread('dataset/train/0a68eeff6e.jpg')

img1 = cv2.resize(image, (224, 224))
#image = np.expand_dims(image, axis=0)
#image = image / 255.0  # normalize pixel values to [0, 1]

model = vit.vit_l32(
    image_size=224,
    activation='sigmoid',
    pretrained_top=False,
    include_top=True,
    pretrained=True,
)

# Load the Keras model
model.load_weights('vit_l32_model_ja')



# Get the attention map
attention_map = visualize.attention_map(vit_model, img1)

# Display the attention map
fig, (ax1, ax2) = plt.subplots(figsize=(10, 10), ncols=2)
ax1.axis('off')
ax2.axis('off')
ax1.set_title('Original')
ax2.set_title('Attention Map')
_ = ax1.imshow(img1)
_ = ax2.imshow(attention_map)

#cv2.waitKey(0)
#cv2.destroyAllWindows()
# Out:
# D:\Analytics\anaconda\lib\site-packages\vit_keras\utils.py:81: UserWarning: Resizing position embeddings from 12, 12 to 7, 7
#   warnings.warn(
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<vit_keras.layers.AddPositionEmbs object at 0x0000020E0C2A7A90> and <vit_keras.layers.TransformerBlock object at 0x0000020E0C2B5AF0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<vit_keras.layers.AddPositionEmbs object at 0x0000020E0C2A7A90> and <vit_keras.layers.TransformerBlock object at 0x0000020E0C2B5AF0>).
# 1/1 [==============================] - 7s 7s/step
